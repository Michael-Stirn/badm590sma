# %%
# This is a notebook to utilize LDA topic modeling for social media data
# and then visualizing it utilizing pyLDAvis

# A lot of this is from websites such as:
# https://www.analyticsvidhya.com/blog/2016/08/beginners-guide-to-topic-modeling-in-python/
# http://hojunhao.github.io/sgparliament/LDA.html

# Conda does not include gensim and pyLDAvis, so you must install those
# via pip install from bash

# %%
# Bring in social media posts from a CSV file
import pandas as pd
import string
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords

# You need to change this file name below to whichever CSV file that you are using
# You also need to change below what the column name in your CSV file is that holds your social media data
# IF YOU ARE PULLING IN FROM NODEXL, MAKE SURE THE FIRST ROW IS THE HEADER NAME!!!
csv_file = 'trumptweets.csv'
data_header = 'Tweet'
twitteryes = 'TRUE'

# Initializing document list for topic modeling
doc_complete = []

# Working with tokenizer specially made for Tweets
tweet_tokenizer = TweetTokenizer()
punct = list(string.punctuation)
stopword_list = stopwords.words('english') + punct + ['rt', 'via', '...'] 

# From Bonzanini
def process(text, tokenizer=TweetTokenizer(), stopwords=[]): 
    text = text.lower() 
    tokens = tokenizer.tokenize(text) 
    return [tok for tok in tokens if tok not in stopwords and not tok.isdigit()]

# If we are dealing with Twitter data
if twitteryes:
    smdata = pd.read_csv(csv_file)
    for line in smdata:
        tokens = process(line, tokenizer=tweet_tokenizer, stopwords=stopword_list) 
        doc_complete.append(tokens)

print("\n Now you have a list called doc_complete that has stored all of your social media posts! \n")

print(smdata)
# Out:
#  Now you have a list called doc_complete that has stored all of your social media posts!
#
#                                                   ﻿Tweet
# 0      #FreeSouthernCameroons\r#FreeALLarrested\r#sto...
# 1      @jlzorzi @mirthalegrand y como fue a la asunci...
# 2      @NewssTrump @Dinkiedow -Yea, DO IT! Miracles d...
# 3      I want .@realDonaldTrump &amp; his incompetent...
# 4      I bet @realDonaldTrump wouldn't want us to kno...
# 5      @realDonaldTrump Why do you always lie? @Barac...
# 6      @Old_Bern_Kenobi @realDonaldTrump - I've been ...
# 7      Estoy totalmente de acuerdo @realDonaldTrump \...
# 8      .@realDonaldTrump vacation last weekend cost t...
# 9      RT @sydneyrachel: lol at anyone who thought a ...
# 10     @realDonaldTrump let's make America grey again...
# 11     RT @realDonaldTrump: Heading to Joint Base And...
# 12     No #WMD &amp; Many 100,000s #Iraqi Civilians K...
# 13     RT @X123Alpha: No #WMD &amp; Many 100,000s #Ir...
# 14     RT @X123Alpha: No #WMD &amp; Many 100,000s #Ir...
# 15     RT @sydneyrachel: lol at anyone who thought a ...
# 16     RT @JoshMalina: .@realdonaldtrump Nice work, d...
# 17     RT @JoshMalina: .@realdonaldtrump Nice work, d...
# 18     RT @realDonaldTrump: Heading to Joint Base And...
# 19     RT @DavidGMcAfee: Haha @realDonaldTrump https:...
# 20     RT @DavidGMcAfee: Haha @realDonaldTrump https:...
# 21     RT @sydneyrachel: lol at anyone who thought a ...
# 22     @FoxNews @PJStrikeForce @HeyTammyBruce @realDo...
# 23     @FoxNews @PJStrikeForce @HeyTammyBruce @realDo...
# 24     @FoxNews @PJStrikeForce @HeyTammyBruce @realDo...
# 25     @FoxNews @PJStrikeForce @HeyTammyBruce @realDo...
# 26       @realDonaldTrump @Potus https://t.co/C26AnQeOe3
# 27       @realDonaldTrump @Potus https://t.co/C26AnQeOe3
# 28     @ColMorrisDavis @POTUS @realDonaldTrump @vicen...
# 29     @ColMorrisDavis @POTUS @realDonaldTrump @vicen...
# ...                                                  ...
# 22149  @realDonaldTrump @VP @PressSec @SenateMajLdr @...
# 22150  @realDonaldTrump @VP @PressSec @SenateMajLdr @...
# 22151  @realDonaldTrump @VP @PressSec @SenateMajLdr @...
# 22152  @realDonaldTrump @VP @PressSec @SenateMajLdr @...
# 22153  @realDonaldTrump @VP @PressSec @SenateMajLdr @...
# 22154  RT @chrissyteigen: Captain's log: 21 days in. ...
# 22155  RT @williamlegate: @realDonaldTrump \r\rHey Do...
# 22156  RT @williamlegate: @realDonaldTrump \r\rHey Do...
# 22157  RT @dannywallace: @realDonaldTrump It's Prime ...
# 22158  RT @dannywallace: @realDonaldTrump It's Prime ...
# 22159                       ____ https://t.co/guJ6lVvObF
# 22160  @realDonaldTrump creepy photo. The Oompa Loomp...
# 22161  Fixed that for you.\r@realDonaldTrump SEE YOU ...
# 22162      Ok, President Donald. https://t.co/2BdP75Wyl1
# 22163  RT @ArmsControlWonk: Ok, President Donald. htt...
# 22164  It's like he actually tries to be a creep. htt...
# 22165  @NajneenF @cnnbrk @realDonaldTrump he's referr...
# 22166  @NajneenF @cnnbrk @realDonaldTrump he's referr...
# 22167  @NajneenF @cnnbrk @realDonaldTrump he's referr...
# 22168  @NajneenF @cnnbrk @realDonaldTrump She's Rache...
# 22169  @NajneenF @cnnbrk @realDonaldTrump She's Rache...
# 22170  @NajneenF @cnnbrk @realDonaldTrump She's Rache...
# 22171  RT @sydneyrachel: lol at anyone who thought a ...
# 22172  RT @DragonflyJonez: Your president is throwing...
# 22173  RT @sydneyrachel: lol at anyone who thought a ...
# 22174  RT @sydneyrachel: lol at anyone who thought a ...
# 22175  RT @FoxNews: .@AriFleischer: Ò@realDonaldTrump...
# 22176  RT @FoxNews: .@AriFleischer: Ò@realDonaldTrump...
# 22177  RT @FoxNews: .@AriFleischer: Ò@realDonaldTrump...
# 22178  RT @sydneyrachel: lol at anyone who thought a ...
#
# [22179 rows x 1 columns]

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]

# %%
# Importing Gensim
import gensim
from gensim import corpora

# Creating the term dictionary of our corpus, where every unique term is assigned an index.
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=5, id2word = dictionary, passes=50)

# %%
# Now import pyLDAvis to visualize
import pyLDAvis.gensim

# %%
# We need to create a corpus in market matrix format
corpora.MmCorpus.serialize('temp.mm', doc_term_matrix)
corpus = corpora.MmCorpus('temp.mm')
print(corpus)
# Out:
# MmCorpus(1 documents, 1 features, 1 non-zero entries)

# %%
# Visualize!
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
#
# 2716   Topic3    25.029749       refugee   117.183396   0.1906  -5.0982
# 196    Topic3    22.392881          many    98.030987   0.2578  -5.2095
# 720    Topic3    14.516705           one    43.632757   0.6338  -5.6430
# 1993   Topic3    12.619633         think    34.135762   0.7392  -5.7830
# 1674   Topic3    46.378402          lyft  1068.789744  -1.4031  -4.4814
# 3255   Topic3    16.772428      business    76.954908   0.2108  -5.4985
# 921    Topic3    10.763677     political    24.611497   0.9073  -5.9421
# 1961   Topic3    19.554254       support   131.288560  -0.1699  -5.3451
# 2474   Topic3    19.453450             u   132.795442  -0.1865  -5.3503
# 953    Topic3    33.591252          aclu   679.344417  -1.2725  -4.8040
# 2037   Topic3    14.338454     president    64.972678   0.2233  -5.6553
# 3195   Topic3    13.412972          also    49.894021   0.4206  -5.7221
# 2810   Topic3    13.023267      american    44.672531   0.5017  -5.7515
# 3361   Topic3    17.653761       million   179.874127  -0.5870  -5.4473
# 2597   Topic3    17.114673       country   185.627306  -0.6495  -5.4783
# 612    Topic3    15.041134       company   111.539393  -0.2693  -5.6075
# 1403   Topic3    13.880015         money    81.575261  -0.0368  -5.6878
#
# [226 rows x 6 columns], token_table=      Topic      Freq          Term
# term
# 517       1  0.934214             1
# 517       3  0.069201             1
# 2786      1  0.980873            1m
# 724       1  0.962343          1mil
# 2662      1  0.853564             4
# 2662      3  0.131317             4
# 287       3  0.914431            75
# 1894      1  0.981475       account
# 953       1  0.849348          aclu
# 953       2  0.100097          aclu
# 953       3  0.050048          aclu
# 103       1  0.034219        action
# 103       2  0.844078        action
# 103       3  0.125471        action
# 601       3  0.984224         alien
# 3195      1  0.681444          also
# 3195      2  0.060127          also
# 3195      3  0.260552          also
# 2879      1  0.910542       amazing
# 2810      1  0.559628      american
# 2810      2  0.134311      american
# 2810      3  0.291007      american
# 2181      3  0.921544          anne
# 822       2  0.985974  antithetical
# 2418      1  0.753326           app
# 2418      2  0.206795           app
# 2418      3  0.044313           app
# 2521      3  0.733449     appointed
# 3181      1  0.153176          area
# 3181      3  0.919058          area
# ...     ...       ...           ...
# 1228      3  0.812656        united
# 829       3  0.817069        unjust
# 1954      1  0.841041           use
# 1954      2  0.146693           use
# 1954      3  0.009780           use
# 2318      1  0.011267         value
# 2318      2  0.985845         value
# 1596      1  0.206184          want
# 1596      2  0.742261          want
# 1596      3  0.051546          want
# 1754      1  0.854023         wasnt
# 1840      1  0.452049           way
# 1840      2  0.069546           way
# 1840      3  0.452049           way
# 2393      2  0.991617       weekend
# 2427      1  0.854022         which
# 2447      1  0.507446          work
# 2447      3  0.479255          work
# 1762      2  0.970119         world
# 1762      3  0.022737         world
# 1870      1  0.535674         would
# 1870      2  0.102033         would
# 1870      3  0.382625         would
# 1452      1  0.384259          year
# 1452      2  0.559681          year
# 1452      3  0.058474          year
# 1983      1  0.308392           you
# 1983      2  0.672855           you
# 1983      3  0.018690           you
# 3309      3  0.956615             •
#
# [329 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 1, 3])
